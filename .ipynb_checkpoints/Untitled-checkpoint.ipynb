# %%
for i in range(1,10):
    mesa5 = i * 5
    for j in range(1,10):
        mesa8 = j * 8
#         print(f"mesa5 = {i}, mesa8 = {j}, total = {(mesa8+mesa5)}")
        if (mesa8 + mesa5) == 36:
            print(f"\n *** \n *** \nmesa5 = {i}, mesa8 = {j}")
# Out:
# mesa5 = 1, mesa8 = 1, total = 13
# mesa5 = 1, mesa8 = 2, total = 21
# mesa5 = 1, mesa8 = 3, total = 29
# mesa5 = 1, mesa8 = 4, total = 37
# mesa5 = 1, mesa8 = 5, total = 45
# mesa5 = 1, mesa8 = 6, total = 53
# mesa5 = 1, mesa8 = 7, total = 61
# mesa5 = 1, mesa8 = 8, total = 69
# mesa5 = 1, mesa8 = 9, total = 77
# mesa5 = 2, mesa8 = 1, total = 18
# mesa5 = 2, mesa8 = 2, total = 26
# mesa5 = 2, mesa8 = 3, total = 34
# mesa5 = 2, mesa8 = 4, total = 42
# mesa5 = 2, mesa8 = 5, total = 50
# mesa5 = 2, mesa8 = 6, total = 58
# mesa5 = 2, mesa8 = 7, total = 66
# mesa5 = 2, mesa8 = 8, total = 74
# mesa5 = 2, mesa8 = 9, total = 82
# mesa5 = 3, mesa8 = 1, total = 23
# mesa5 = 3, mesa8 = 2, total = 31
# mesa5 = 3, mesa8 = 3, total = 39
# mesa5 = 3, mesa8 = 4, total = 47
# mesa5 = 3, mesa8 = 5, total = 55
# mesa5 = 3, mesa8 = 6, total = 63
# mesa5 = 3, mesa8 = 7, total = 71
# mesa5 = 3, mesa8 = 8, total = 79
# mesa5 = 3, mesa8 = 9, total = 87
# mesa5 = 4, mesa8 = 1, total = 28
# ...
